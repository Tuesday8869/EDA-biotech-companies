# %% [markdown]
# <a href="https://colab.research.google.com/github/Tuesday8869/EDA-biotech-companies/blob/main/health_and_pharma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Biotechnology Funding Analysis Using Exploratory Data Analysis and Data Visualization

# %% [markdown]
# # **Project Summary -**
# # Project Summary
#
# This project focuses on analyzing a biotechnology funding dataset containing 1,208 funding and acquisition records from 2009 to 2026. The objective of the project is to explore investment trends, identify major funding patterns, and understand the relationships between different variables using Exploratory Data Analysis (EDA) and Data Visualization.
#
# The dataset includes information such as deal date, year, deal type, investors, target companies, deal value (in USD billions), megadeal status, and headline authenticity. Before analysis, the dataset was examined for missing values, duplicates, data types, and overall structure. The data was found to be clean and suitable for analysis with minimal preprocessing.
#
# Various visualizations, including bar charts, line charts, pie charts, histograms, box plots, scatter plots, correlation heatmaps, and pair plots, were created to identify trends and patterns. The analysis revealed that 2021 recorded the highest number of biotech deals, normal funding deals dominated the industry, and only a few megadeals accounted for exceptionally high investment values. It also highlighted the most active investors, the most-funded companies, and the distribution of funding across different deal types.
#
# The project provides valuable business insights that can help investors, biotechnology companies, and decision-makers understand market behavior, identify growth opportunities, improve investment strategies, and support data-driven decision-making. Overall, the analysis demonstrates how data visualization and exploratory data analysis can transform raw funding data into meaningful information that supports strategic business planning in the biotechnology sector.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The biotechnology industry has experienced rapid growth in funding, investments, and acquisitions over the years. However, due to the large volume of investment data, it is difficult for businesses and investors to identify funding trends, major investors, high-value deals, and emerging market opportunities. This project aims to analyze biotechnology funding data using data visualization and exploratory data analysis (EDA) to uncover meaningful patterns and provide insights that support better investment decisions and business strategies

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# business objective of this project is to analyze biotechnology funding and acquisition data to identify investment trends, funding patterns, and key market players. The analysis aims to understand how funding has changed over the years, which deal types are most common, which companies and investors are most active, and how megadeals contribute to the overall biotechnology industry.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/biotech_funding.csv'
df = pd.read_csv(path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#   deal_id        date  year deal_type acquirer_or_investors target_or_company  \
# 0   D0001  2009-03-09  2009       M&A                Pfizer             Wyeth
# 1   D0041  2010-01-08  2010  Series_B       F-Prime Capital         Oncgen OS
# 2   D0036  2010-01-12  2010       IPO        Public markets         Yothap IO
# 3   D0045  2010-01-16  2010       M&A                 Roche         Aermod AB
# 4   D0053  2010-01-17  2010  Series_B      Polaris Partners         Tavyot OS
#
#    value_usd_bn              description  is_megadeal  is_real_headline
# 0        68.000  Pfizer-Wyeth megamerger            1                 1
# 1         0.403            Series_B 2010            0                 0
# 2         0.456                 IPO 2010            0                 0
# 3         1.158                 M&A 2010            0                 0
# 4         0.643            Series_B 2010            0                 0

# %%
df.tail()
# Out:
#      deal_id        date  year  deal_type acquirer_or_investors  \
# 1203   D1207  2026-02-07  2026         VC               OrbiMed
# 1204   D1203  2026-04-02  2026   Series_B         Atlas Venture
# 1205   D1208  2026-04-13  2026         VC   Flagship Pioneering
# 1206   D1204  2026-04-16  2026  Crossover              a16z Bio
# 1207   D1205  2026-04-17  2026   Series_C   Flagship Pioneering
#
#         target_or_company  value_usd_bn     description  is_megadeal  \
# 1203  Aerlum Therapeutics         0.065         VC 2026            0
# 1204            Modden ON         0.122   Series_B 2026            0
# 1205            Moduni IO         0.229         VC 2026            0
# 1206            Yotpro Tx         0.183  Crossover 2026            0
# 1207            Synkym RX         0.010   Series_C 2026            0
#
#       is_real_headline
# 1203                 0
# 1204                 0
# 1205                 0
# 1206                 0
# 1207                 0

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(f'Number of rows in Dataset are : {df.shape[0]} \nNumber of columns in Dataset are : {df.shape[1]}')
# Out:
# Number of rows in Dataset are : 1208
# Number of columns in Dataset are : 10

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1208 entries, 0 to 1207
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   deal_id                1208 non-null   object
#  1   date                   1208 non-null   object
#  2   year                   1208 non-null   int64
#  3   deal_type              1208 non-null   object
#  4   acquirer_or_investors  1208 non-null   object
#  5   target_or_company      1208 non-null   object
#  6   value_usd_bn           1208 non-null   float64
#  7   description            1208 non-null   object
#  8   is_megadeal            1208 non-null   int64
#  9   is_real_headline       1208 non-null   int64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 94.5+ KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
# Visualizing the missing values
df.isnull().sum().plot(kind='bar', figsize=(12,5))
plt.title("Missing Values Count")
plt.xlabel("Columns")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset is a structured and clean collection of 1208 biotechnology funding and acquisition records. It captures investment activity over multiple years and provides valuable information about deal types, investors, companies, funding values, and megadeals. Its completeness and variety of variables make it suitable for business analysis, storytelling through visualizations, and identifying trends in the biotechnology industry.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['deal_id', 'date', 'year', 'deal_type', 'acquirer_or_investors',
#        'target_or_company', 'value_usd_bn', 'description', 'is_megadeal',
#        'is_real_headline'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#               year  value_usd_bn  is_megadeal  is_real_headline
# count  1208.000000   1208.000000  1208.000000       1208.000000
# mean   2018.653974      1.614002     0.039735          0.022351
# std       4.281844      6.730375     0.195417          0.147884
# min    2009.000000      0.005000     0.000000          0.000000
# 25%    2015.000000      0.095000     0.000000          0.000000
# 50%    2019.000000      0.208000     0.000000          0.000000
# 75%    2022.000000      0.486250     0.000000          0.000000
# max    2026.000000     74.000000     1.000000          1.000000

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()
# Out:
# deal_id                  1208
# date                     1053
# year                       18
# deal_type                   6
# acquirer_or_investors      34
# target_or_company        1083
# value_usd_bn              632
# description               125
# is_megadeal                 2
# is_real_headline            2
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
#Removing Missing Values
df.dropna(inplace=True)
# Correct data types
df['date'] = pd.to_datetime(df['date'])

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/content/biotech_funding.csv')

df.boxplot(figsize=(10,6))
plt.title('Box Plot of Numerical Variables')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Since MY dataset is already fairly clean, here are some insights that i gathered:
# The dataset contains 1208 records and 10 variables.
# The dataset is clean, with no missing values and no major data quality issues.
# Most variables are categorical, while year and value_usd_bn are the main numerical variables.
# Most biotech deals have relatively small investment values, while only a few are very large (megadeals).
# 2021 recorded the highest number of biotech deals, indicating strong investment activity.
# Normal deals make up the majority of transactions, while megadeals are relatively rare.
# Funding is concentrated among a few companies and investors.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/content/biotech_funding.csv')
year_counts = df['year'].value_counts().sort_index()

plt.figure(figsize=(10,5))
year_counts.plot(kind='bar')
plt.title('Number of Biotech Deals by Year')
plt.xlabel('Year')
plt.ylabel('Number of Deals')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is ideal for comparing the number of deals across different years because each year is a separate category. It makes it easy to identify the year with the highest or lowest number of deals.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar chart shows that 2021 was the most active year for biotech funding, with 133 recorded deals. Funding activity generally increased from 2010 to 2021, indicating sustained growth in the biotechnology sector. Although the number of deals declined slightly after 2021, investment activity remained relatively strong in subsequent years. The unusually low counts for 2009 and 2026 are likely due to incomplete data rather than reduced investment activity

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights have a positive business impact because they help stakeholders understand investment trends, identify growth opportunities, optimize funding strategies, and make informed business decisions based on historical biotech funding activity.

# %% [markdown]
# #### Chart - 2

# %%
deal_counts = df['deal_type'].value_counts()

plt.figure(figsize=(8,5))
deal_counts.plot(kind='bar')
plt.title('Distribution of Deal Types')
plt.xlabel('Deal Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was chosen because deal_type is a categorical variable. Bar charts are the most suitable visualization for comparing the frequency or count of different categories. They make it easy to identify which deal types are most common and which are least common by comparing the heights of the bars.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart clearly shows which deal type occurs most frequently in the biotech industry.
# It helps identify the dominant investment or transaction method used in the dataset.
# Some deal types have significantly higher counts than others, indicating that certain funding methods are preferred over others.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights help businesses and investors understand which deal types are most popular in the biotechnology industry. Companies seeking funding can focus on the investment methods that are most commonly used, increasing their chances of securing capital. Investors can also identify where the market is most active and allocate resources accordingly. This supports better financial planning, investment strategies, and business decision-making.

# %% [markdown]
# #### Chart - 3

# %%
import matplotlib.pyplot as plt

df['is_megadeal'].value_counts().plot(kind='pie',
                                      labels=['Normal Deal','Megadeal'],
                                      autopct='%1.1f%%')

plt.title('Megadeals vs Normal Deals')
plt.ylabel('')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart was chosen because it is the most suitable chart for showing the proportion or percentage of different categories within a whole. Since the variable is_megadeal has only two categories (Megadeal and Normal Deal), the pie chart clearly displays their percentage distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pie chart shows the percentage distribution of megadeals and normal deals in the biotechnology industry.
# It indicates that normal deals make up the majority of the transactions, while megadeals account for only a small proportion.
# This suggests that the biotech sector is driven mainly by small and medium-sized investments, whereas very large funding deals are relatively uncommon.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights help businesses and investors understand the overall funding pattern in the biotech industry. Since most transactions are normal deals, startups and growing companies can focus on attracting regular investments rather than relying only on rare megadeals.

# %% [markdown]
# #### Chart - 4

# %%
plt.figure(figsize=(8,5))
plt.hist(df['value_usd_bn'], bins=20)
plt.title('Distribution of Deal Values')
plt.xlabel('Deal Value (USD Billion)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram was chosen because value_usd_bn is a continuous numerical variable. Histograms are the most suitable charts for showing how numerical values are distributed across different ranges. They help identify where most deal values are concentrated, whether the data is evenly distributed, and whether there are unusually high or low values.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histogram shows that most biotech deals have relatively low funding values, while only a small number of deals have very high values.
# The distribution is right-skewed (positively skewed), meaning that small and medium-sized deals are much more common than large deals.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The histogram helps investors and companies understand the typical range of funding in the biotech industry. Businesses can set realistic funding targets by comparing themselves with the most common deal values.

# %% [markdown]
# #### Chart - 5

# %%
plt.figure(figsize=(6,5))
plt.boxplot(df['value_usd_bn'])
plt.title('Box Plot of Deal Values')
plt.ylabel('USD Billion')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot was chosen because it is the best chart for identifying outliers and understanding the spread of a numerical variable. Since value_usd_bn contains continuous numerical data, the box plot effectively shows the median, quartiles, range, and unusually high or low deal values. It provides a quick summary of the overall distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The box plot shows that most biotech deals are concentrated within a relatively low value range.
# There are several outliers above the upper whisker, representing a few extremely high-value deals (megadeals).
# The median lies closer to the lower end of the data, indicating that most deals have smaller values, while only a few deals are exceptionally large

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The box plot helps businesses and investors understand the typical funding range while also identifying unusually large investments. Companies can benchmark their funding expectations against the median deal value, and investors can identify exceptional deals that may represent high-growth opportunities

# %% [markdown]
# #### Chart - 6

# %%
avg_value = df.groupby('year')['value_usd_bn'].mean()

plt.figure(figsize=(10,5))
plt.plot(avg_value.index, avg_value.values, marker='o')
plt.title('Average Deal Value by Year')
plt.xlabel('Year')
plt.ylabel('Average Value (USD Billion)')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart was chosen because it is the most appropriate chart for showing trends over time. Since the data is organized by year, a line chart clearly illustrates how the average deal value has increased or decreased across different years, making it easy to identify long-term patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows how the average value of biotech deals has changed over the years.
# It identifies years with higher and lower average investment values.
# Fluctuations in the line indicate that investment values vary from year to year due to changing market conditions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The chart helps businesses and investors understand long-term funding trends and identify periods when average investments were higher. Companies can use these insights to plan fundraising, expansion, and budgeting, while investors can make more informed decisions about future investment opportunities.

# %% [markdown]
# #### Chart - 7

# %%
top_companies = df['target_or_company'].value_counts().head(10)

plt.figure(figsize=(10,6))
top_companies.plot(kind='barh')
plt.title('Top 10 Most Funded Companies')
plt.xlabel('Number of Deals')
plt.ylabel('Company')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart was chosen because company names are generally long, making them easier to read horizontally. It is the best chart for comparing and ranking the top 10 companies based on the number of funding deals they received.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart identifies the top 10 companies that received the highest number of funding deals.
# It shows that a few companies attracted significantly more investments than others.
# The chart highlights which companies have gained the highest investor confidence and market attention.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The chart helps investors identify companies with strong growth potential and consistent investor interest. Businesses can study the strategies of these highly funded companies to improve their own fundraising efforts. It also helps investors and companies identify opportunities for partnerships, acquisitions, and future investments.

# %% [markdown]
# #### Chart - 8

# %%
top_investors = df['acquirer_or_investors'].value_counts().head(10)

plt.figure(figsize=(10,6))
top_investors.plot(kind='barh')
plt.title('Top 10 Investors by Number of Deals')
plt.xlabel('Number of Deals')
plt.ylabel('Investor')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart was chosen because investor names are often long, making them easier to read horizontally. It is the most suitable chart for comparing the number of deals made by different investors and ranking them from highest to lowest.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart identifies the top 10 most active investors in the biotechnology industry.
# It shows which investors participated in the largest number of funding or acquisition deals.
# A few investors dominate the market by making significantly more deals than others.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The chart helps companies identify investors who actively fund biotech businesses. Startups can target these investors when seeking funding, while investors can benchmark their activity against competitors. This information also helps businesses build strategic partnerships and improve fundraising opportunities.

# %% [markdown]
# #### Chart - 9

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['year'], df['value_usd_bn'])
plt.title('Deal Value Across Years')
plt.xlabel('Year')
plt.ylabel('Deal Value (USD Billion)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot was chosen because it is the most suitable chart for showing the relationship between two numerical variables: year and deal value. It helps identify trends, clusters, and outliers, making it easy to observe whether deal values have changed over time.

# %% [markdown]
# ### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The scatter plot shows how deal values are distributed across different years.
# Most deals have relatively low investment values, while a few deals have exceptionally high values, appearing as outliers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The scatter plot helps investors and businesses understand how investment values vary over time. It enables companies to identify years with significant investments, assess market behavior, and make informed decisions regarding funding, expansion, and future investment strategies. It also helps in recognizing unusual high-value deals that may indicate major market opportunities.

# %% [markdown]
# #### Chart - 10

# %%
headline = df['is_real_headline'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(headline,
        labels=['Real Headline','Not Real'],
        autopct='%1.1f%%',
        startangle=90)
plt.title('Real vs Fake Headlines')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart was chosen because it is the most suitable chart for showing the proportion or percentage of categories within a whole. Since the variable is_real_headline has only two categories (Real and Not Real), the pie chart clearly displays the percentage of each category

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the percentage of real and non-real headlines in the dataset.
# It helps evaluate the reliability and composition of the dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights help businesses and researchers assess the reliability of the dataset before performing analysis or building machine learning models. A dataset with a high proportion of real headlines improves the accuracy of business insights, predictive models, and decision-making. It also increases confidence in the results obtained from the data.

# %% [markdown]
# #### Chart - 11

# %%
megadeals = df[df['is_megadeal'] == 1].groupby('year').size()

plt.figure(figsize=(8,5))
megadeals.plot(kind='bar')
plt.title('Megadeals by Year')
plt.xlabel('Year')
plt.ylabel('Number of Megadeals')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was chosen because it is the most suitable chart for comparing the number of megadeals across different years. Each year is a separate category, and the bar chart makes it easy to identify which years had the highest and lowest number of megadeals.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the annual distribution of megadeals in the biotechnology industry.
# It identifies the years in which the highest number of megadeals occurred, indicating periods of increased large-scale investment activity.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The chart helps businesses and investors identify periods when large investments were more common. Companies can use this information to plan fundraising, expansion, or acquisitions during favorable market conditions. Investors can also recognize years with strong investment activity and use historical trends to improve future investment decisions.

# %% [markdown]
# #### Chart - 12

# %%
top10 = df.nlargest(10, 'value_usd_bn')

plt.figure(figsize=(10,6))
plt.barh(top10['target_or_company'], top10['value_usd_bn'])
plt.title('Top 10 Highest Value Deals')
plt.xlabel('Deal Value (USD Billion)')
plt.ylabel('Company')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart was chosen because it is ideal for comparing ranked values when category names (company names) are long. It clearly displays the top 10 highest-value deals and makes it easy to compare their investment values.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart identifies the top 10 companies with the highest-value biotech deals.
# It shows that a few companies received exceptionally large investments compared to others.
# There is a noticeable difference between the highest-value deals and the remaining companies, indicating that large investments are concentrated among a small number of organizations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The chart helps investors identify companies with strong market confidence and high investment potential. Businesses can study these successful companies to understand the factors that attracted large investments. This information can improve investment decisions, support strategic partnerships, and help companies develop better fundraising strategies.

# %% [markdown]
# #### Chart - 13

# %%
year_value = df.groupby('year')['value_usd_bn'].sum()

plt.figure(figsize=(10,5))
plt.plot(year_value.index, year_value.values, marker='o')
plt.title('Total Investment Value by Year')
plt.xlabel('Year')
plt.ylabel('Total Value (USD Billion)')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart was chosen because it is the most suitable visualization for showing changes and trends over time. Since the data is grouped by year, a line chart clearly illustrates how the total investment value has increased or decreased across different years and makes it easy to identify growth patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart identifies the year with the highest total investment value.
# It shows how total biotech funding has changed over time.
# Some years experienced significant increases in investment, indicating periods of strong market growth.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights help businesses and investors identify years with strong investment activity and understand long-term funding trends. Companies can use this information to determine favorable periods for fundraising or expansion, while investors can plan their investments based on historical market performance. These insights support better financial planning, forecasting, and strategic decision-making.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('/content/biotech_funding.csv')

sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap was chosen because it provides a visual representation of the correlation between multiple numerical variables at the same time. It helps identify strong positive, negative, or weak relationships using color intensity, making it easier to understand how variables are related.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap shows the strength and direction of relationships between numerical variables.
# Variables with values close to +1 are strongly positively correlated.
# Variables with values close to −1 are strongly negatively correlated.
# Values close to 0 indicate little or no relationship.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The heatmap helps businesses and investors identify which variables are related. Understanding these relationships supports better decision-making, improves predictive modeling, and helps identify the factors associated with large investments or megadeals. It also assists analysts in selecting the most relevant variables for business analysis.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('/content/biotech_funding.csv')

sns.pairplot(df[['year','value_usd_bn','is_megadeal','is_real_headline']])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot was chosen because it allows multiple numerical variables to be compared simultaneously. It displays scatter plots for every pair of variables and histograms along the diagonal, making it easy to observe distributions, trends, correlations, and potential outliers in a single visualization.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pair plot shows the relationship between year, deal value, megadeal status, and real headline status.
# Most deal values are concentrated at lower amounts, while a few high-value deals appear as outliers.
# The is_megadeal variable is associated with higher deal values, indicating that megadeals generally involve larger investments.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The pair plot provides valuable insights into relationships among numerical variables and highlights that high-value investments are concentrated in relatively few deals. While this information helps improve investment strategies, it also reveals that unequal funding distribution may limit the growth of emerging biotech companies

# %% [markdown]
# Teams and analysts can use these insights to understand common winning patterns and improve match strategies. The distributions also help assess how competitive IPL matches typically are. There is no direct indication of negative growth, but if the data shows a rise in extreme winning margins, it may indicate more one-sided matches, which could reduce competitiveness and fan engagement.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# These are some things which i observed during the analysis and should suggest the client in order to achieve his business objective:
# Invest during high-growth periods
# The analysis shows that some years experienced significantly higher funding activity than others. The client should identify the factors behind these successful years and plan investments during similar market conditions.
# Focus on the most common deal types
# Since certain deal types occur more frequently, the client should prioritize these funding methods to increase the likelihood of successful investments and partnerships.
# Diversify investment across companies
# Instead of concentrating funds on only a few large companies, the client should invest in a mix of established firms and promising startups. This reduces investment risk and encourages innovation.
# Monitor megadeals and market leaders
# Large-value deals often indicate companies with strong growth potential. Tracking these companies and investors can help identify future business opportunities and strategic partnerships.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Overall, the biotechnology industry demonstrates strong investment potential with consistent funding activity and increasing investor interest over the years. While most deals are moderate in size, a few megadeals significantly influence the market. The analysis provides valuable insights for investment planning, business strategy, and market forecasting, while also highlighting the need for a more balanced distribution of funding to support the growth of emerging biotech companies.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
